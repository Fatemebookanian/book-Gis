# %%
fhand =open('payannameh.txt')
payannameh = fhand.read()
text = payannameh.split()

count = 0
for word in text:
    word = word.lower()
    if word == 'برنامک':
        count += 1
print(count)
# Out:
# 32

# %%
fhand =open('payannameh.txt')
payannameh = fhand.read()
text = payannameh.split()

count = 0
words = {}
for word in text:
    word = word.lower()
    if word in words:
        words[word]+=1
    else:
        words[word] = 1
print(words)
# Out:
# {'چکيده:': 1, '\u200f': 179, 'با': 42, 'توجه': 6, 'به': 106, 'رشد': 2, 'فناوري\u200cهاي': 1, 'هوشمند،': 3, 'استفاده': 44, 'نوآورانه': 1, 'از': 115, 'تکنولوژي': 1, 'ها': 3, 'در': 122, 'حمل\u200cونقل': 39, 'مي\u200cتواند': 7, 'بهبود': 10, 'زندگي': 4, 'ساکنان': 1, 'شهري': 8, 'کمک': 10, 'کند.': 1, 'امروزه': 1, 'برنامه\u200cهاي': 2, 'برنامه\u200cريزي': 15, 'سفر': 49, 'و': 227, 'مسيريابي': 7, 'عنصري': 1, 'جدانشدني': 1, 'شهري،': 4, 'تبديل': 2, 'شده': 31, 'است.': 12, 'اين': 57, 'فناوري\u200cها': 1, 'نه': 2, 'تنها': 5, 'راحتي': 3, 'کارايي': 4, 'سفرهاي': 11, 'را': 45, 'افزايش': 9, 'مي\u200cدهند،': 2, 'بلکه': 2, 'مي\u200cتوانند': 6, 'نقش': 5, 'مهمي': 5, 'تحقق': 2, 'اهداف': 2, 'توسعه': 6, 'پايدار': 3, 'داشته': 7, 'باشند.\u200f': 1, 'راستا،': 2, 'آسيب\u200cشناسي': 2, 'بررسي': 9, 'کاربردي': 1, 'برنامک\u200cها': 6, 'تجربه': 6, 'سامانه': 2, 'حمل': 37, 'نقل': 40, 'همگاني': 23, 'کاهش': 6, 'چالش\u200cهاي': 3, 'ترافيکي': 2, 'حائز': 1, 'اهميت': 4, 'هدف': 4, 'مطالعه،': 1, 'شناسايي': 3, 'نقاط': 3, 'قوت': 1
# ...
